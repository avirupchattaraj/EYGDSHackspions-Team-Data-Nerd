# %%
import pandas as pd
import numpy as np
import missingno as msno
import spacy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from textblob import TextBlob
import re
import preprocessor as p
from wordcloud import WordCloud

# %%
plt.style.use('fivethirtyeight')

# %%
df=pd.read_excel("data.xlsx")

# %%
df
# Out:
#                            UniversalMessageId SocialNetwork  \
# 0               TWITTER_8_1271507282027614208       TWITTER
# 1               TWITTER_8_1271506336262623234       TWITTER
# 2               TWITTER_4_1271505174297796609       TWITTER
# 3     WEB_98_7489736133816419a2fbec1a9e2ada24           WEB
# 4               TWITTER_8_1271502174699339777       TWITTER
# ...                                       ...           ...
# 3948            TWITTER_8_1269699240651087872       TWITTER
# 3949            TWITTER_2_1269699202365435905       TWITTER
# 3950            TWITTER_8_1269698792091275265       TWITTER
# 3951            TWITTER_8_1269698611929124866       TWITTER
# 3952            TWITTER_2_1269698192574160897       TWITTER
#
#                           SenderUserId SenderScreenName  \
# 0                             76649744         abagdadi
# 1                            108473360      techvignesh
# 2                           2817687492    ReworkAmerica
# 3     449D069DD1505A8F8256A8734600D562      Tait Lawton
# 4                             30482756     Milanowekpet
# ...                                ...              ...
# 3948                          19284888       Nicochan33
# 3949                         220089132      mserracanta
# 3950                        1139524920         IEAKwame
# 3951                          84274680     OmerAtakoglu
# 3952                         102045464         jakobssm
#
#                   SenderListedName  \
# 0                    anwer bagdadi
# 1             Vignesh Varadharajan
# 2                   Rework America
# 3                      Tait Lawton
# 4                 Peter Schellinck
# ...                            ...
# 3948                 Nicolas Babin
# 3949            Miquel Serracanta🎗
# 3950                   Kwame Owino
# 3951                 Ömer Atakoğlu
# 3952  Jakob Schiøtt Stenbæk Madsen
#
#                                     SenderProfileImgUrl  SenderProfileLink  \
# 0     https://pbs.twimg.com/profile_images/773954554...                NaN
# 1     https://pbs.twimg.com/profile_images/126785507...                NaN
# 2     https://pbs.twimg.com/profile_images/913020134...                NaN
# 3                                                   NaN                NaN
# 4     https://pbs.twimg.com/profile_images/231007149...                NaN
# ...                                                 ...                ...
# 3948  https://pbs.twimg.com/profile_images/773909130...                NaN
# 3949  https://pbs.twimg.com/profile_images/124908614...                NaN
# 3950  https://pbs.twimg.com/profile_images/327166249...                NaN
# 3951  https://pbs.twimg.com/profile_images/752486315...                NaN
# 3952  https://pbs.twimg.com/profile_images/252404970...                NaN
#
#       Sender Followers Count  SenderInfluencerScore  SenderAge  ... Retweets  \
# 0                     2646.0                    NaN        NaN  ...      NaN
# 1                      507.0                    NaN        NaN  ...      NaN
# 2                     1718.0                    NaN        NaN  ...      NaN
# 3                        0.0                    NaN        NaN  ...      NaN
# 4                     2218.0                    NaN        NaN  ...      NaN
# ...                      ...                    ...        ...  ...      ...
# 3948                 78387.0                    NaN        NaN  ...      NaN
# 3949                  1301.0                    NaN        NaN  ...      1.0
# 3950                 40302.0                    NaN        NaN  ...      NaN
# 3951                  1346.0                    NaN        NaN  ...      NaN
# 3952                  1988.0                    NaN        NaN  ...      2.0
#
#           Tweet Generator                             Location       Country  \
# 0      Twitter for iPhone                                  NaN           NaN
# 1      Twitter for iPhone  Johannesburg, Gauteng, South Africa  South Africa
# 2          Traject Social                                  NaN           NaN
# 3                     NaN                                  NaN        Canada
# 4      Twitter for iPhone                                  NaN           NaN
# ...                   ...                                  ...           ...
# 3948  Twitter for Android                               France        France
# 3949   Twitter for iPhone                     Catalonia, Spain         Spain
# 3950  Twitter for Android                                  NaN           NaN
# 3951   Twitter for iPhone                     Istanbul, Turkey        Turkey
# 3952   Twitter for iPhone                              Denmark       Denmark
#
#           State          City  Latitude Longitude Sender Email  \
# 0           NaN           NaN       NaN       NaN          NaN
# 1       Gauteng  Johannesburg -26.20227  28.04363          NaN
# 2           NaN           NaN       NaN       NaN          NaN
# 3           NaN           NaN   0.00000   0.00000          NaN
# 4           NaN           NaN       NaN       NaN          NaN
# ...         ...           ...       ...       ...          ...
# 3948        NaN           NaN  46.00000   2.00000          NaN
# 3949  Catalonia           NaN  41.82046   1.86768          NaN
# 3950        NaN           NaN       NaN       NaN          NaN
# 3951   Istanbul           NaN  41.03508  28.98331          NaN
# 3952        NaN           NaN  56.00000  10.00000          NaN
#
#          Message Type
# 0     Twitter Retweet
# 1     Twitter Retweet
# 2     Twitter Mention
# 3           Blog Post
# 4     Twitter Retweet
# ...               ...
# 3948  Twitter Retweet
# 3949   Twitter Update
# 3950  Twitter Retweet
# 3951  Twitter Retweet
# 3952   Twitter Update
#
# [3953 rows x 33 columns]

# %%
msno.bar(df,color='red')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['UniversalMessageId', 'SocialNetwork', 'SenderUserId',
#        'SenderScreenName', 'SenderListedName', 'SenderProfileImgUrl',
#        'SenderProfileLink', 'Sender Followers Count', 'SenderInfluencerScore',
#        'SenderAge', 'SenderGender', 'OriginalAuthor',
#        'OriginalAuthorProfileLink', 'Title', 'Message', 'MessageType',
#        'CreatedTime', 'Language', 'LanguageCode', 'CountryCode',
#        'MediaTypeList', 'Permalink', 'Domain', 'Retweets', 'Tweet Generator',
#        'Location', 'Country', 'State', 'City', 'Latitude', 'Longitude',
#        'Sender Email', 'Message Type'],
#       dtype='object')

# %%
df.isna().sum()*100/len(df)
# Out:
# UniversalMessageId             0.000000
# SocialNetwork                  0.000000
# SenderUserId                   2.858588
# SenderScreenName               2.858588
# SenderListedName               2.858588
# SenderProfileImgUrl           27.523400
# SenderProfileLink            100.000000
# Sender Followers Count         2.858588
# SenderInfluencerScore        100.000000
# SenderAge                    100.000000
# SenderGender                  93.751581
# OriginalAuthor                66.607640
# OriginalAuthorProfileLink     66.607640
# Title                         72.830761
# Message                        0.050594
# MessageType                    0.000000
# CreatedTime                    0.000000
# Language                       0.000000
# LanguageCode                   0.000000
# CountryCode                   26.182646
# MediaTypeList                 24.943081
# Permalink                      0.505945
# Domain                         0.505945
# Retweets                      93.119150
# Tweet Generator               28.737668
# Location                      49.253731
# Country                       26.182646
# State                         63.394890
# City                          71.818872
# Latitude                      26.182646
# Longitude                     26.182646
# Sender Email                 100.000000
# Message Type                   0.000000
# dtype: float64

# %% [markdown]
# ### Dropping all the columns having first of all 100 percent

# %%
df.drop(['SenderProfileLink','SenderInfluencerScore','SenderAge','Sender Email'],axis=1,inplace=True)

# %%
df
# Out:
#                            UniversalMessageId SocialNetwork  \
# 0               TWITTER_8_1271507282027614208       TWITTER
# 1               TWITTER_8_1271506336262623234       TWITTER
# 2               TWITTER_4_1271505174297796609       TWITTER
# 3     WEB_98_7489736133816419a2fbec1a9e2ada24           WEB
# 4               TWITTER_8_1271502174699339777       TWITTER
# ...                                       ...           ...
# 3948            TWITTER_8_1269699240651087872       TWITTER
# 3949            TWITTER_2_1269699202365435905       TWITTER
# 3950            TWITTER_8_1269698792091275265       TWITTER
# 3951            TWITTER_8_1269698611929124866       TWITTER
# 3952            TWITTER_2_1269698192574160897       TWITTER
#
#                           SenderUserId SenderScreenName  \
# 0                             76649744         abagdadi
# 1                            108473360      techvignesh
# 2                           2817687492    ReworkAmerica
# 3     449D069DD1505A8F8256A8734600D562      Tait Lawton
# 4                             30482756     Milanowekpet
# ...                                ...              ...
# 3948                          19284888       Nicochan33
# 3949                         220089132      mserracanta
# 3950                        1139524920         IEAKwame
# 3951                          84274680     OmerAtakoglu
# 3952                         102045464         jakobssm
#
#                   SenderListedName  \
# 0                    anwer bagdadi
# 1             Vignesh Varadharajan
# 2                   Rework America
# 3                      Tait Lawton
# 4                 Peter Schellinck
# ...                            ...
# 3948                 Nicolas Babin
# 3949            Miquel Serracanta🎗
# 3950                   Kwame Owino
# 3951                 Ömer Atakoğlu
# 3952  Jakob Schiøtt Stenbæk Madsen
#
#                                     SenderProfileImgUrl  \
# 0     https://pbs.twimg.com/profile_images/773954554...
# 1     https://pbs.twimg.com/profile_images/126785507...
# 2     https://pbs.twimg.com/profile_images/913020134...
# 3                                                   NaN
# 4     https://pbs.twimg.com/profile_images/231007149...
# ...                                                 ...
# 3948  https://pbs.twimg.com/profile_images/773909130...
# 3949  https://pbs.twimg.com/profile_images/124908614...
# 3950  https://pbs.twimg.com/profile_images/327166249...
# 3951  https://pbs.twimg.com/profile_images/752486315...
# 3952  https://pbs.twimg.com/profile_images/252404970...
#
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink  ...                     Domain Retweets  \
# 0       https://twitter.com/McKinsey  ...                twitter.com      NaN
# 1       https://twitter.com/McKinsey  ...                twitter.com      NaN
# 2                                NaN  ...                twitter.com      NaN
# 3                                NaN  ...  nanjingmarketinggroup.com      NaN
# 4       https://twitter.com/McKonGov  ...                twitter.com      NaN
# ...                              ...  ...                        ...      ...
# 3948    https://twitter.com/McKinsey  ...                twitter.com      NaN
# 3949                             NaN  ...                twitter.com      1.0
# 3950    https://twitter.com/McKinsey  ...                twitter.com      NaN
# 3951  https://twitter.com/retailgeek  ...                twitter.com      NaN
# 3952                             NaN  ...                twitter.com      2.0
#
#           Tweet Generator                             Location       Country  \
# 0      Twitter for iPhone                                  NaN           NaN
# 1      Twitter for iPhone  Johannesburg, Gauteng, South Africa  South Africa
# 2          Traject Social                                  NaN           NaN
# 3                     NaN                                  NaN        Canada
# 4      Twitter for iPhone                                  NaN           NaN
# ...                   ...                                  ...           ...
# 3948  Twitter for Android                               France        France
# 3949   Twitter for iPhone                     Catalonia, Spain         Spain
# 3950  Twitter for Android                                  NaN           NaN
# 3951   Twitter for iPhone                     Istanbul, Turkey        Turkey
# 3952   Twitter for iPhone                              Denmark       Denmark
#
#           State          City  Latitude Longitude     Message Type
# 0           NaN           NaN       NaN       NaN  Twitter Retweet
# 1       Gauteng  Johannesburg -26.20227  28.04363  Twitter Retweet
# 2           NaN           NaN       NaN       NaN  Twitter Mention
# 3           NaN           NaN   0.00000   0.00000        Blog Post
# 4           NaN           NaN       NaN       NaN  Twitter Retweet
# ...         ...           ...       ...       ...              ...
# 3948        NaN           NaN  46.00000   2.00000  Twitter Retweet
# 3949  Catalonia           NaN  41.82046   1.86768   Twitter Update
# 3950        NaN           NaN       NaN       NaN  Twitter Retweet
# 3951   Istanbul           NaN  41.03508  28.98331  Twitter Retweet
# 3952        NaN           NaN  56.00000  10.00000   Twitter Update
#
# [3953 rows x 29 columns]

# %%
df.drop("UniversalMessageId",axis=1,inplace=True)

# %%
df
# Out:
#      SocialNetwork                      SenderUserId SenderScreenName  \
# 0          TWITTER                          76649744         abagdadi
# 1          TWITTER                         108473360      techvignesh
# 2          TWITTER                        2817687492    ReworkAmerica
# 3              WEB  449D069DD1505A8F8256A8734600D562      Tait Lawton
# 4          TWITTER                          30482756     Milanowekpet
# ...            ...                               ...              ...
# 3948       TWITTER                          19284888       Nicochan33
# 3949       TWITTER                         220089132      mserracanta
# 3950       TWITTER                        1139524920         IEAKwame
# 3951       TWITTER                          84274680     OmerAtakoglu
# 3952       TWITTER                         102045464         jakobssm
#
#                   SenderListedName  \
# 0                    anwer bagdadi
# 1             Vignesh Varadharajan
# 2                   Rework America
# 3                      Tait Lawton
# 4                 Peter Schellinck
# ...                            ...
# 3948                 Nicolas Babin
# 3949            Miquel Serracanta🎗
# 3950                   Kwame Owino
# 3951                 Ömer Atakoğlu
# 3952  Jakob Schiøtt Stenbæk Madsen
#
#                                     SenderProfileImgUrl  \
# 0     https://pbs.twimg.com/profile_images/773954554...
# 1     https://pbs.twimg.com/profile_images/126785507...
# 2     https://pbs.twimg.com/profile_images/913020134...
# 3                                                   NaN
# 4     https://pbs.twimg.com/profile_images/231007149...
# ...                                                 ...
# 3948  https://pbs.twimg.com/profile_images/773909130...
# 3949  https://pbs.twimg.com/profile_images/124908614...
# 3950  https://pbs.twimg.com/profile_images/327166249...
# 3951  https://pbs.twimg.com/profile_images/752486315...
# 3952  https://pbs.twimg.com/profile_images/252404970...
#
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#       ...                     Domain Retweets      Tweet Generator  \
# 0     ...                twitter.com      NaN   Twitter for iPhone
# 1     ...                twitter.com      NaN   Twitter for iPhone
# 2     ...                twitter.com      NaN       Traject Social
# 3     ...  nanjingmarketinggroup.com      NaN                  NaN
# 4     ...                twitter.com      NaN   Twitter for iPhone
# ...   ...                        ...      ...                  ...
# 3948  ...                twitter.com      NaN  Twitter for Android
# 3949  ...                twitter.com      1.0   Twitter for iPhone
# 3950  ...                twitter.com      NaN  Twitter for Android
# 3951  ...                twitter.com      NaN   Twitter for iPhone
# 3952  ...                twitter.com      2.0   Twitter for iPhone
#
#                                  Location       Country      State  \
# 0                                     NaN           NaN        NaN
# 1     Johannesburg, Gauteng, South Africa  South Africa    Gauteng
# 2                                     NaN           NaN        NaN
# 3                                     NaN        Canada        NaN
# 4                                     NaN           NaN        NaN
# ...                                   ...           ...        ...
# 3948                               France        France        NaN
# 3949                     Catalonia, Spain         Spain  Catalonia
# 3950                                  NaN           NaN        NaN
# 3951                     Istanbul, Turkey        Turkey   Istanbul
# 3952                              Denmark       Denmark        NaN
#
#               City  Latitude Longitude     Message Type
# 0              NaN       NaN       NaN  Twitter Retweet
# 1     Johannesburg -26.20227  28.04363  Twitter Retweet
# 2              NaN       NaN       NaN  Twitter Mention
# 3              NaN   0.00000   0.00000        Blog Post
# 4              NaN       NaN       NaN  Twitter Retweet
# ...            ...       ...       ...              ...
# 3948           NaN  46.00000   2.00000  Twitter Retweet
# 3949           NaN  41.82046   1.86768   Twitter Update
# 3950           NaN       NaN       NaN  Twitter Retweet
# 3951           NaN  41.03508  28.98331  Twitter Retweet
# 3952           NaN  56.00000  10.00000   Twitter Update
#
# [3953 rows x 28 columns]

# %%
df.drop(["SenderUserId","SenderScreenName","SenderListedName"],axis=1,inplace=True)

# %%
df
# Out:
#      SocialNetwork                                SenderProfileImgUrl  \
# 0          TWITTER  https://pbs.twimg.com/profile_images/773954554...
# 1          TWITTER  https://pbs.twimg.com/profile_images/126785507...
# 2          TWITTER  https://pbs.twimg.com/profile_images/913020134...
# 3              WEB                                                NaN
# 4          TWITTER  https://pbs.twimg.com/profile_images/231007149...
# ...            ...                                                ...
# 3948       TWITTER  https://pbs.twimg.com/profile_images/773909130...
# 3949       TWITTER  https://pbs.twimg.com/profile_images/124908614...
# 3950       TWITTER  https://pbs.twimg.com/profile_images/327166249...
# 3951       TWITTER  https://pbs.twimg.com/profile_images/752486315...
# 3952       TWITTER  https://pbs.twimg.com/profile_images/252404970...
#
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message      MessageType  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...  Twitter Retweet
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...  Twitter Retweet
# 2     This @McKinsey article provides us with some f...  Twitter Mention
# 3     10 Chinese Market Trends Since COVID-19 Toggle...        Blog Post
# 4     RT @McKonGov In a war, leadership up and down ...  Twitter Retweet
# ...                                                 ...              ...
# 3948  RT @McKinsey When can your region reopen? TY @...  Twitter Retweet
# 3949             To read!! mckinsey.com/business-funct…   Twitter Update
# 3950  RT @McKinsey When can your region reopen? This...  Twitter Retweet
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...  Twitter Retweet
# 3952  As cities end coronavirus lockdowns, public-tr...   Twitter Update
#
#                  CreatedTime  ...                     Domain Retweets  \
# 0    2020-06-12 18:18:54.155  ...                twitter.com      NaN
# 1    2020-06-12 18:15:08.667  ...                twitter.com      NaN
# 2    2020-06-12 18:10:31.633  ...                twitter.com      NaN
# 3    2020-06-12 18:04:00.000  ...  nanjingmarketinggroup.com      NaN
# 4    2020-06-12 17:58:36.473  ...                twitter.com      NaN
# ...                      ...  ...                        ...      ...
# 3948 2020-06-07 18:34:23.499  ...                twitter.com      NaN
# 3949 2020-06-07 18:34:14.371  ...                twitter.com      1.0
# 3950 2020-06-07 18:32:36.554  ...                twitter.com      NaN
# 3951 2020-06-07 18:31:53.600  ...                twitter.com      NaN
# 3952 2020-06-07 18:30:13.618  ...                twitter.com      2.0
#
#           Tweet Generator                             Location       Country  \
# 0      Twitter for iPhone                                  NaN           NaN
# 1      Twitter for iPhone  Johannesburg, Gauteng, South Africa  South Africa
# 2          Traject Social                                  NaN           NaN
# 3                     NaN                                  NaN        Canada
# 4      Twitter for iPhone                                  NaN           NaN
# ...                   ...                                  ...           ...
# 3948  Twitter for Android                               France        France
# 3949   Twitter for iPhone                     Catalonia, Spain         Spain
# 3950  Twitter for Android                                  NaN           NaN
# 3951   Twitter for iPhone                     Istanbul, Turkey        Turkey
# 3952   Twitter for iPhone                              Denmark       Denmark
#
#           State          City  Latitude Longitude     Message Type
# 0           NaN           NaN       NaN       NaN  Twitter Retweet
# 1       Gauteng  Johannesburg -26.20227  28.04363  Twitter Retweet
# 2           NaN           NaN       NaN       NaN  Twitter Mention
# 3           NaN           NaN   0.00000   0.00000        Blog Post
# 4           NaN           NaN       NaN       NaN  Twitter Retweet
# ...         ...           ...       ...       ...              ...
# 3948        NaN           NaN  46.00000   2.00000  Twitter Retweet
# 3949  Catalonia           NaN  41.82046   1.86768   Twitter Update
# 3950        NaN           NaN       NaN       NaN  Twitter Retweet
# 3951   Istanbul           NaN  41.03508  28.98331  Twitter Retweet
# 3952        NaN           NaN  56.00000  10.00000   Twitter Update
#
# [3953 rows x 25 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
data_platform=dict(df['SocialNetwork'].value_counts())

# %%
data_platform.keys()
# Out:
# dict_keys(['TWITTER', 'WEB', 'FACEBOOK', 'PRINT', 'REDDIT', 'INSTAGRAM'])

# %%
plt.title("Data Collected from platform")
plt.xlabel("Social Media Platform")
plt.ylabel("Count")
sns.barplot(x=list(data_platform.keys()),y=list(data_platform.values()),data=df)
# Out:
# <AxesSubplot:title={'center':'Data Collected from platform'}, xlabel='Social Media Platform', ylabel='Count'>

# %%
df.drop('SocialNetwork',axis=1,inplace=True)

# %%
df
# Out:
#                                     SenderProfileImgUrl  \
# 0     https://pbs.twimg.com/profile_images/773954554...
# 1     https://pbs.twimg.com/profile_images/126785507...
# 2     https://pbs.twimg.com/profile_images/913020134...
# 3                                                   NaN
# 4     https://pbs.twimg.com/profile_images/231007149...
# ...                                                 ...
# 3948  https://pbs.twimg.com/profile_images/773909130...
# 3949  https://pbs.twimg.com/profile_images/124908614...
# 3950  https://pbs.twimg.com/profile_images/327166249...
# 3951  https://pbs.twimg.com/profile_images/752486315...
# 3952  https://pbs.twimg.com/profile_images/252404970...
#
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message      MessageType  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...  Twitter Retweet
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...  Twitter Retweet
# 2     This @McKinsey article provides us with some f...  Twitter Mention
# 3     10 Chinese Market Trends Since COVID-19 Toggle...        Blog Post
# 4     RT @McKonGov In a war, leadership up and down ...  Twitter Retweet
# ...                                                 ...              ...
# 3948  RT @McKinsey When can your region reopen? TY @...  Twitter Retweet
# 3949             To read!! mckinsey.com/business-funct…   Twitter Update
# 3950  RT @McKinsey When can your region reopen? This...  Twitter Retweet
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...  Twitter Retweet
# 3952  As cities end coronavirus lockdowns, public-tr...   Twitter Update
#
#                  CreatedTime Language  ...                     Domain  \
# 0    2020-06-12 18:18:54.155  English  ...                twitter.com
# 1    2020-06-12 18:15:08.667  English  ...                twitter.com
# 2    2020-06-12 18:10:31.633  English  ...                twitter.com
# 3    2020-06-12 18:04:00.000  English  ...  nanjingmarketinggroup.com
# 4    2020-06-12 17:58:36.473  English  ...                twitter.com
# ...                      ...      ...  ...                        ...
# 3948 2020-06-07 18:34:23.499  English  ...                twitter.com
# 3949 2020-06-07 18:34:14.371  English  ...                twitter.com
# 3950 2020-06-07 18:32:36.554  English  ...                twitter.com
# 3951 2020-06-07 18:31:53.600  English  ...                twitter.com
# 3952 2020-06-07 18:30:13.618  English  ...                twitter.com
#
#      Retweets      Tweet Generator                             Location  \
# 0         NaN   Twitter for iPhone                                  NaN
# 1         NaN   Twitter for iPhone  Johannesburg, Gauteng, South Africa
# 2         NaN       Traject Social                                  NaN
# 3         NaN                  NaN                                  NaN
# 4         NaN   Twitter for iPhone                                  NaN
# ...       ...                  ...                                  ...
# 3948      NaN  Twitter for Android                               France
# 3949      1.0   Twitter for iPhone                     Catalonia, Spain
# 3950      NaN  Twitter for Android                                  NaN
# 3951      NaN   Twitter for iPhone                     Istanbul, Turkey
# 3952      2.0   Twitter for iPhone                              Denmark
#
#            Country      State          City  Latitude Longitude  \
# 0              NaN        NaN           NaN       NaN       NaN
# 1     South Africa    Gauteng  Johannesburg -26.20227  28.04363
# 2              NaN        NaN           NaN       NaN       NaN
# 3           Canada        NaN           NaN   0.00000   0.00000
# 4              NaN        NaN           NaN       NaN       NaN
# ...            ...        ...           ...       ...       ...
# 3948        France        NaN           NaN  46.00000   2.00000
# 3949         Spain  Catalonia           NaN  41.82046   1.86768
# 3950           NaN        NaN           NaN       NaN       NaN
# 3951        Turkey   Istanbul           NaN  41.03508  28.98331
# 3952       Denmark        NaN           NaN  56.00000  10.00000
#
#          Message Type
# 0     Twitter Retweet
# 1     Twitter Retweet
# 2     Twitter Mention
# 3           Blog Post
# 4     Twitter Retweet
# ...               ...
# 3948  Twitter Retweet
# 3949   Twitter Update
# 3950  Twitter Retweet
# 3951  Twitter Retweet
# 3952   Twitter Update
#
# [3953 rows x 24 columns]

# %%
data_platform=dict(df['Country'].value_counts()[:10])

# %%
data_platform
# Out:
# {'United States': 1116,
#  'United Kingdom': 347,
#  'India': 203,
#  'Canada': 132,
#  'Spain': 132,
#  'France': 72,
#  'South Africa': 65,
#  'Australia': 65,
#  'Germany': 55,
#  'Italy': 51}

# %%
fig=plt.figure(figsize=(15,5))
plt.title("Data Generated By Countries")
plt.xlabel("Country")
plt.ylabel("Message Count")
sns.barplot(x=list(data_platform.keys()),y=list(data_platform.values()),data=df)
# Out:
# <AxesSubplot:title={'center':'Data Generated By Countries'}, xlabel='Country', ylabel='Message Count'>

# %%
df.drop('Country',axis=1,inplace=True)

# %%
df
# Out:
#                                     SenderProfileImgUrl  \
# 0     https://pbs.twimg.com/profile_images/773954554...
# 1     https://pbs.twimg.com/profile_images/126785507...
# 2     https://pbs.twimg.com/profile_images/913020134...
# 3                                                   NaN
# 4     https://pbs.twimg.com/profile_images/231007149...
# ...                                                 ...
# 3948  https://pbs.twimg.com/profile_images/773909130...
# 3949  https://pbs.twimg.com/profile_images/124908614...
# 3950  https://pbs.twimg.com/profile_images/327166249...
# 3951  https://pbs.twimg.com/profile_images/752486315...
# 3952  https://pbs.twimg.com/profile_images/252404970...
#
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message      MessageType  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...  Twitter Retweet
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...  Twitter Retweet
# 2     This @McKinsey article provides us with some f...  Twitter Mention
# 3     10 Chinese Market Trends Since COVID-19 Toggle...        Blog Post
# 4     RT @McKonGov In a war, leadership up and down ...  Twitter Retweet
# ...                                                 ...              ...
# 3948  RT @McKinsey When can your region reopen? TY @...  Twitter Retweet
# 3949             To read!! mckinsey.com/business-funct…   Twitter Update
# 3950  RT @McKinsey When can your region reopen? This...  Twitter Retweet
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...  Twitter Retweet
# 3952  As cities end coronavirus lockdowns, public-tr...   Twitter Update
#
#                  CreatedTime Language  ...  \
# 0    2020-06-12 18:18:54.155  English  ...
# 1    2020-06-12 18:15:08.667  English  ...
# 2    2020-06-12 18:10:31.633  English  ...
# 3    2020-06-12 18:04:00.000  English  ...
# 4    2020-06-12 17:58:36.473  English  ...
# ...                      ...      ...  ...
# 3948 2020-06-07 18:34:23.499  English  ...
# 3949 2020-06-07 18:34:14.371  English  ...
# 3950 2020-06-07 18:32:36.554  English  ...
# 3951 2020-06-07 18:31:53.600  English  ...
# 3952 2020-06-07 18:30:13.618  English  ...
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain Retweets      Tweet Generator  \
# 0                   twitter.com      NaN   Twitter for iPhone
# 1                   twitter.com      NaN   Twitter for iPhone
# 2                   twitter.com      NaN       Traject Social
# 3     nanjingmarketinggroup.com      NaN                  NaN
# 4                   twitter.com      NaN   Twitter for iPhone
# ...                         ...      ...                  ...
# 3948                twitter.com      NaN  Twitter for Android
# 3949                twitter.com      1.0   Twitter for iPhone
# 3950                twitter.com      NaN  Twitter for Android
# 3951                twitter.com      NaN   Twitter for iPhone
# 3952                twitter.com      2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#      Longitude     Message Type
# 0          NaN  Twitter Retweet
# 1     28.04363  Twitter Retweet
# 2          NaN  Twitter Mention
# 3      0.00000        Blog Post
# 4          NaN  Twitter Retweet
# ...        ...              ...
# 3948   2.00000  Twitter Retweet
# 3949   1.86768   Twitter Update
# 3950       NaN  Twitter Retweet
# 3951  28.98331  Twitter Retweet
# 3952  10.00000   Twitter Update
#
# [3953 rows x 23 columns]

# %%
df['MessageType'].value_counts()
# Out:
# Twitter Retweet      1320
# News                  828
# Twitter Update        775
# Twitter Mention       691
# Blog Post             197
# Facebook Post          45
# Twitter Reply          32
# Print News             20
# Forums                 14
# Instagram Post         14
# Reddit Comment          9
# Reddit Submission       6
# Facebook Replies        1
# Facebook Comment        1
# Name: MessageType, dtype: int64

# %%
data_platform=dict(df['MessageType'].value_counts())
fig=plt.figure(figsize=(15,5))
plt.title("Message Type and Counts")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=45)
sns.barplot(x=list(data_platform.keys()),y=list(data_platform.values()),data=df)
# Out:
# <AxesSubplot:title={'center':'Message Type and Counts'}, xlabel='Country', ylabel='Count'>

# %%
df.drop('MessageType',axis=1,inplace=True)

# %%
df
# Out:
#                                     SenderProfileImgUrl  \
# 0     https://pbs.twimg.com/profile_images/773954554...
# 1     https://pbs.twimg.com/profile_images/126785507...
# 2     https://pbs.twimg.com/profile_images/913020134...
# 3                                                   NaN
# 4     https://pbs.twimg.com/profile_images/231007149...
# ...                                                 ...
# 3948  https://pbs.twimg.com/profile_images/773909130...
# 3949  https://pbs.twimg.com/profile_images/124908614...
# 3950  https://pbs.twimg.com/profile_images/327166249...
# 3951  https://pbs.twimg.com/profile_images/752486315...
# 3952  https://pbs.twimg.com/profile_images/252404970...
#
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime Language LanguageCode  ...  \
# 0    2020-06-12 18:18:54.155  English           en  ...
# 1    2020-06-12 18:15:08.667  English           en  ...
# 2    2020-06-12 18:10:31.633  English           en  ...
# 3    2020-06-12 18:04:00.000  English           en  ...
# 4    2020-06-12 17:58:36.473  English           en  ...
# ...                      ...      ...          ...  ...
# 3948 2020-06-07 18:34:23.499  English           en  ...
# 3949 2020-06-07 18:34:14.371  English           en  ...
# 3950 2020-06-07 18:32:36.554  English           en  ...
# 3951 2020-06-07 18:31:53.600  English           en  ...
# 3952 2020-06-07 18:30:13.618  English           en  ...
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain Retweets      Tweet Generator  \
# 0                   twitter.com      NaN   Twitter for iPhone
# 1                   twitter.com      NaN   Twitter for iPhone
# 2                   twitter.com      NaN       Traject Social
# 3     nanjingmarketinggroup.com      NaN                  NaN
# 4                   twitter.com      NaN   Twitter for iPhone
# ...                         ...      ...                  ...
# 3948                twitter.com      NaN  Twitter for Android
# 3949                twitter.com      1.0   Twitter for iPhone
# 3950                twitter.com      NaN  Twitter for Android
# 3951                twitter.com      NaN   Twitter for iPhone
# 3952                twitter.com      2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#      Longitude     Message Type
# 0          NaN  Twitter Retweet
# 1     28.04363  Twitter Retweet
# 2          NaN  Twitter Mention
# 3      0.00000        Blog Post
# 4          NaN  Twitter Retweet
# ...        ...              ...
# 3948   2.00000  Twitter Retweet
# 3949   1.86768   Twitter Update
# 3950       NaN  Twitter Retweet
# 3951  28.98331  Twitter Retweet
# 3952  10.00000   Twitter Update
#
# [3953 rows x 22 columns]

# %%
df.drop("SenderProfileImgUrl",axis=1,inplace=True)

# %%
df
# Out:
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime Language LanguageCode CountryCode  ...  \
# 0    2020-06-12 18:18:54.155  English           en         NaN  ...
# 1    2020-06-12 18:15:08.667  English           en          ZA  ...
# 2    2020-06-12 18:10:31.633  English           en         NaN  ...
# 3    2020-06-12 18:04:00.000  English           en          CA  ...
# 4    2020-06-12 17:58:36.473  English           en         NaN  ...
# ...                      ...      ...          ...         ...  ...
# 3948 2020-06-07 18:34:23.499  English           en          FR  ...
# 3949 2020-06-07 18:34:14.371  English           en          ES  ...
# 3950 2020-06-07 18:32:36.554  English           en         NaN  ...
# 3951 2020-06-07 18:31:53.600  English           en          TR  ...
# 3952 2020-06-07 18:30:13.618  English           en          DK  ...
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain Retweets      Tweet Generator  \
# 0                   twitter.com      NaN   Twitter for iPhone
# 1                   twitter.com      NaN   Twitter for iPhone
# 2                   twitter.com      NaN       Traject Social
# 3     nanjingmarketinggroup.com      NaN                  NaN
# 4                   twitter.com      NaN   Twitter for iPhone
# ...                         ...      ...                  ...
# 3948                twitter.com      NaN  Twitter for Android
# 3949                twitter.com      1.0   Twitter for iPhone
# 3950                twitter.com      NaN  Twitter for Android
# 3951                twitter.com      NaN   Twitter for iPhone
# 3952                twitter.com      2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#       Longitude     Message Type
# 0           NaN  Twitter Retweet
# 1      28.04363  Twitter Retweet
# 2           NaN  Twitter Mention
# 3       0.00000        Blog Post
# 4           NaN  Twitter Retweet
# ...         ...              ...
# 3948    2.00000  Twitter Retweet
# 3949    1.86768   Twitter Update
# 3950        NaN  Twitter Retweet
# 3951   28.98331  Twitter Retweet
# 3952   10.00000   Twitter Update
#
# [3953 rows x 21 columns]

# %%
df.drop("CountryCode",axis=1,inplace=True)

# %%
df
# Out:
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime Language LanguageCode MediaTypeList  \
# 0    2020-06-12 18:18:54.155  English           en         PHOTO
# 1    2020-06-12 18:15:08.667  English           en         VIDEO
# 2    2020-06-12 18:10:31.633  English           en          LINK
# 3    2020-06-12 18:04:00.000  English           en          LINK
# 4    2020-06-12 17:58:36.473  English           en         PHOTO
# ...                      ...      ...          ...           ...
# 3948 2020-06-07 18:34:23.499  English           en           NaN
# 3949 2020-06-07 18:34:14.371  English           en          LINK
# 3950 2020-06-07 18:32:36.554  English           en         PHOTO
# 3951 2020-06-07 18:31:53.600  English           en          LINK
# 3952 2020-06-07 18:30:13.618  English           en          LINK
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain  Retweets      Tweet Generator  \
# 0                   twitter.com       NaN   Twitter for iPhone
# 1                   twitter.com       NaN   Twitter for iPhone
# 2                   twitter.com       NaN       Traject Social
# 3     nanjingmarketinggroup.com       NaN                  NaN
# 4                   twitter.com       NaN   Twitter for iPhone
# ...                         ...       ...                  ...
# 3948                twitter.com       NaN  Twitter for Android
# 3949                twitter.com       1.0   Twitter for iPhone
# 3950                twitter.com       NaN  Twitter for Android
# 3951                twitter.com       NaN   Twitter for iPhone
# 3952                twitter.com       2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#       Longitude     Message Type
# 0           NaN  Twitter Retweet
# 1      28.04363  Twitter Retweet
# 2           NaN  Twitter Mention
# 3       0.00000        Blog Post
# 4           NaN  Twitter Retweet
# ...         ...              ...
# 3948    2.00000  Twitter Retweet
# 3949    1.86768   Twitter Update
# 3950        NaN  Twitter Retweet
# 3951   28.98331  Twitter Retweet
# 3952   10.00000   Twitter Update
#
# [3953 rows x 20 columns]

# %%
df['Language'].value_counts()
# Out:
# English    3953
# Name: Language, dtype: int64

# %%
df.drop(['Language','LanguageCode'],axis=1,inplace=True)

# %%
df
# Out:
#       Sender Followers Count SenderGender OriginalAuthor  \
# 0                     2646.0          NaN       McKinsey
# 1                      507.0          NaN       McKinsey
# 2                     1718.0          NaN            NaN
# 3                        0.0          NaN            NaN
# 4                     2218.0            M       McKonGov
# ...                      ...          ...            ...
# 3948                 78387.0            M       McKinsey
# 3949                  1301.0          NaN            NaN
# 3950                 40302.0          NaN       McKinsey
# 3951                  1346.0          NaN     retailgeek
# 3952                  1988.0            M            NaN
#
#            OriginalAuthorProfileLink                                    Title  \
# 0       https://twitter.com/McKinsey                                      NaN
# 1       https://twitter.com/McKinsey                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN  10 Chinese Market Trends Since COVID-19
# 4       https://twitter.com/McKonGov                                      NaN
# ...                              ...                                      ...
# 3948    https://twitter.com/McKinsey                                      NaN
# 3949                             NaN                                      NaN
# 3950    https://twitter.com/McKinsey                                      NaN
# 3951  https://twitter.com/retailgeek                                      NaN
# 3952                             NaN                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime MediaTypeList  \
# 0    2020-06-12 18:18:54.155         PHOTO
# 1    2020-06-12 18:15:08.667         VIDEO
# 2    2020-06-12 18:10:31.633          LINK
# 3    2020-06-12 18:04:00.000          LINK
# 4    2020-06-12 17:58:36.473         PHOTO
# ...                      ...           ...
# 3948 2020-06-07 18:34:23.499           NaN
# 3949 2020-06-07 18:34:14.371          LINK
# 3950 2020-06-07 18:32:36.554         PHOTO
# 3951 2020-06-07 18:31:53.600          LINK
# 3952 2020-06-07 18:30:13.618          LINK
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain  Retweets      Tweet Generator  \
# 0                   twitter.com       NaN   Twitter for iPhone
# 1                   twitter.com       NaN   Twitter for iPhone
# 2                   twitter.com       NaN       Traject Social
# 3     nanjingmarketinggroup.com       NaN                  NaN
# 4                   twitter.com       NaN   Twitter for iPhone
# ...                         ...       ...                  ...
# 3948                twitter.com       NaN  Twitter for Android
# 3949                twitter.com       1.0   Twitter for iPhone
# 3950                twitter.com       NaN  Twitter for Android
# 3951                twitter.com       NaN   Twitter for iPhone
# 3952                twitter.com       2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#       Longitude     Message Type
# 0           NaN  Twitter Retweet
# 1      28.04363  Twitter Retweet
# 2           NaN  Twitter Mention
# 3       0.00000        Blog Post
# 4           NaN  Twitter Retweet
# ...         ...              ...
# 3948    2.00000  Twitter Retweet
# 3949    1.86768   Twitter Update
# 3950        NaN  Twitter Retweet
# 3951   28.98331  Twitter Retweet
# 3952   10.00000   Twitter Update
#
# [3953 rows x 18 columns]

# %%
df['Tweet Generator'].value_counts()[:20]
# Out:
# Twitter Web App        853
# Twitter for iPhone     596
# Twitter for Android    358
# LinkedIn               157
# IFTTT                  148
# Buffer                 118
# Hootsuite Inc.         106
# Twitter for iPad        80
# dlvr.it                 68
# Sprinklr                68
# TweetDeck               50
# Sprout Social           31
# HubSpot                 25
# Paper.li                16
# GaggleAMP               12
# Dynamic Signal           8
# Scoop.it                 7
# ContentStudio.io         6
# EveryoneSocial           6
# Powered by Sprinklr      5
# Name: Tweet Generator, dtype: int64

# %%
df.drop(['SenderGender','Sender Followers Count'],axis=1,inplace=True)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime MediaTypeList  \
# 0    2020-06-12 18:18:54.155         PHOTO
# 1    2020-06-12 18:15:08.667         VIDEO
# 2    2020-06-12 18:10:31.633          LINK
# 3    2020-06-12 18:04:00.000          LINK
# 4    2020-06-12 17:58:36.473         PHOTO
# ...                      ...           ...
# 3948 2020-06-07 18:34:23.499           NaN
# 3949 2020-06-07 18:34:14.371          LINK
# 3950 2020-06-07 18:32:36.554         PHOTO
# 3951 2020-06-07 18:31:53.600          LINK
# 3952 2020-06-07 18:30:13.618          LINK
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain  Retweets      Tweet Generator  \
# 0                   twitter.com       NaN   Twitter for iPhone
# 1                   twitter.com       NaN   Twitter for iPhone
# 2                   twitter.com       NaN       Traject Social
# 3     nanjingmarketinggroup.com       NaN                  NaN
# 4                   twitter.com       NaN   Twitter for iPhone
# ...                         ...       ...                  ...
# 3948                twitter.com       NaN  Twitter for Android
# 3949                twitter.com       1.0   Twitter for iPhone
# 3950                twitter.com       NaN  Twitter for Android
# 3951                twitter.com       NaN   Twitter for iPhone
# 3952                twitter.com       2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#       Longitude     Message Type
# 0           NaN  Twitter Retweet
# 1      28.04363  Twitter Retweet
# 2           NaN  Twitter Mention
# 3       0.00000        Blog Post
# 4           NaN  Twitter Retweet
# ...         ...              ...
# 3948    2.00000  Twitter Retweet
# 3949    1.86768   Twitter Update
# 3950        NaN  Twitter Retweet
# 3951   28.98331  Twitter Retweet
# 3952   10.00000   Twitter Update
#
# [3953 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['OriginalAuthor', 'OriginalAuthorProfileLink', 'Title', 'Message',
#        'CreatedTime', 'MediaTypeList', 'Permalink', 'Domain', 'Retweets',
#        'Tweet Generator', 'Location', 'State', 'City', 'Latitude', 'Longitude',
#        'Message Type'],
#       dtype='object')

# %%
data_platform=dict(df['OriginalAuthor'].value_counts()[:10])

# %%
fig=plt.figure(figsize=(15,5))
plt.title("Top Original Authors")
plt.xlabel("Original Author")
plt.ylabel("Count")
plt.xticks(rotation=45)
sns.barplot(x=list(data_platform.keys()),y=list(data_platform.values()),data=df)
# Out:
# <AxesSubplot:title={'center':'Top Original Authors'}, xlabel='Original Author', ylabel='Count'>

# %%
df['splitted_message']=df['Message'].apply(lambda message:str(message).split())

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime MediaTypeList  \
# 0    2020-06-12 18:18:54.155         PHOTO
# 1    2020-06-12 18:15:08.667         VIDEO
# 2    2020-06-12 18:10:31.633          LINK
# 3    2020-06-12 18:04:00.000          LINK
# 4    2020-06-12 17:58:36.473         PHOTO
# ...                      ...           ...
# 3948 2020-06-07 18:34:23.499           NaN
# 3949 2020-06-07 18:34:14.371          LINK
# 3950 2020-06-07 18:32:36.554         PHOTO
# 3951 2020-06-07 18:31:53.600          LINK
# 3952 2020-06-07 18:30:13.618          LINK
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain  Retweets      Tweet Generator  \
# 0                   twitter.com       NaN   Twitter for iPhone
# 1                   twitter.com       NaN   Twitter for iPhone
# 2                   twitter.com       NaN       Traject Social
# 3     nanjingmarketinggroup.com       NaN                  NaN
# 4                   twitter.com       NaN   Twitter for iPhone
# ...                         ...       ...                  ...
# 3948                twitter.com       NaN  Twitter for Android
# 3949                twitter.com       1.0   Twitter for iPhone
# 3950                twitter.com       NaN  Twitter for Android
# 3951                twitter.com       NaN   Twitter for iPhone
# 3952                twitter.com       2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#       Longitude     Message Type  \
# 0           NaN  Twitter Retweet
# 1      28.04363  Twitter Retweet
# 2           NaN  Twitter Mention
# 3       0.00000        Blog Post
# 4           NaN  Twitter Retweet
# ...         ...              ...
# 3948    2.00000  Twitter Retweet
# 3949    1.86768   Twitter Update
# 3950        NaN  Twitter Retweet
# 3951   28.98331  Twitter Retweet
# 3952   10.00000   Twitter Update
#
#                                        splitted_message
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
# [3953 rows x 17 columns]

# %%
df['Message'].values
# Out:
# array(['RT @McKinsey Beyond the #COVID19 crisis, preparing for the jobs of tomorrow will challenge every community across the EU. @McKinsey_MGI just launched a new report on the #FutureofWork in Europe. mck.co/2YsrNgK https://t.co/OKDO2UTubS',
#        'RT @McKinsey We’re tracking #COVID19’s impact on jobs by income levels, race, age groups and gender. Find this and other interactive charts and resources in our COVID Response Center. mck.co/3f8MPYu https://t.co/ujz5SREMML',
#        'This @McKinsey article provides us with some food for thought as we start to think about where to go next after the Coronavirus crisis and how we can create a path to the new normal.\n\nqoo.ly/36hqzi',
#        ...,
#        'RT @McKinsey When can your region reopen? This local response matrix balances virus spread vis-a-vis public-health system readiness. mck.co/3cuSDdd #chartoftheday #dataviz https://t.co/Q82J22NcwS',
#        'RT @retailgeek Starbucks China: Pre-Covid 15% digital orders, Peak-Covid 80% digital orders, Post Shelter-in-Place 27% digital orders.  (12% channel shift to digital after stores reopened) mckinsey.com/industries/ret… via @McKinsey',
#        'As cities end coronavirus lockdowns, public-transit authorities will need ways to increase ridership—safely. Early attempts in some European cities can offer lessons to those elsewhere in Europe.\n #publictransit #dktrp\nmckinsey.com/industries/tra…'],
#       dtype=object)

# %%
tweet="RT @McKinsey Beyond the #COVID19 crisis"
tweet = re.sub(r'^RT[\s]+', '', tweet)
print(tweet)
# Out:
# @McKinsey Beyond the #COVID19 crisis

# %%
tweet1="#handsome #style #skirt #girl #awesome100"
tweet = re.findall(r'#[a-zA-Z]+',tweet1)

# %%
tweet
# Out:
# ['#handsome', '#style', '#skirt', '#girl', '#awesome']

# %%
def hashtag_finder(message):
    tweet = re.findall(r'#[a-zA-Z]+',str(message))
    hashtags=""
    for i in tweet:
        hashtags+=i
        hashtags+=" "
    return hashtags

# %%
p.clean(df['Message'].iloc[0])
# Out:
# 'Beyond the crisis, preparing for the jobs of tomorrow will challenge every community across the EU. just launched a new report on the in Europe.'

# %%
df['hashtag']=df['splitted_message'].apply(hashtag_finder)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime MediaTypeList  \
# 0    2020-06-12 18:18:54.155         PHOTO
# 1    2020-06-12 18:15:08.667         VIDEO
# 2    2020-06-12 18:10:31.633          LINK
# 3    2020-06-12 18:04:00.000          LINK
# 4    2020-06-12 17:58:36.473         PHOTO
# ...                      ...           ...
# 3948 2020-06-07 18:34:23.499           NaN
# 3949 2020-06-07 18:34:14.371          LINK
# 3950 2020-06-07 18:32:36.554         PHOTO
# 3951 2020-06-07 18:31:53.600          LINK
# 3952 2020-06-07 18:30:13.618          LINK
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain  Retweets      Tweet Generator  \
# 0                   twitter.com       NaN   Twitter for iPhone
# 1                   twitter.com       NaN   Twitter for iPhone
# 2                   twitter.com       NaN       Traject Social
# 3     nanjingmarketinggroup.com       NaN                  NaN
# 4                   twitter.com       NaN   Twitter for iPhone
# ...                         ...       ...                  ...
# 3948                twitter.com       NaN  Twitter for Android
# 3949                twitter.com       1.0   Twitter for iPhone
# 3950                twitter.com       NaN  Twitter for Android
# 3951                twitter.com       NaN   Twitter for iPhone
# 3952                twitter.com       2.0   Twitter for iPhone
#
#                                  Location      State          City  Latitude  \
# 0                                     NaN        NaN           NaN       NaN
# 1     Johannesburg, Gauteng, South Africa    Gauteng  Johannesburg -26.20227
# 2                                     NaN        NaN           NaN       NaN
# 3                                     NaN        NaN           NaN   0.00000
# 4                                     NaN        NaN           NaN       NaN
# ...                                   ...        ...           ...       ...
# 3948                               France        NaN           NaN  46.00000
# 3949                     Catalonia, Spain  Catalonia           NaN  41.82046
# 3950                                  NaN        NaN           NaN       NaN
# 3951                     Istanbul, Turkey   Istanbul           NaN  41.03508
# 3952                              Denmark        NaN           NaN  56.00000
#
#       Longitude     Message Type  \
# 0           NaN  Twitter Retweet
# 1      28.04363  Twitter Retweet
# 2           NaN  Twitter Mention
# 3       0.00000        Blog Post
# 4           NaN  Twitter Retweet
# ...         ...              ...
# 3948    2.00000  Twitter Retweet
# 3949    1.86768   Twitter Update
# 3950        NaN  Twitter Retweet
# 3951   28.98331  Twitter Retweet
# 3952   10.00000   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
# [3953 rows x 18 columns]

# %%
df.drop(['Tweet Generator','Location','State','City','Latitude','Longitude'],axis=1,inplace=True)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides us with some f...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In a war, leadership up and down ...
# ...                                                 ...
# 3948  RT @McKinsey When can your region reopen? TY @...
# 3949             To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When can your region reopen? This...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                  CreatedTime MediaTypeList  \
# 0    2020-06-12 18:18:54.155         PHOTO
# 1    2020-06-12 18:15:08.667         VIDEO
# 2    2020-06-12 18:10:31.633          LINK
# 3    2020-06-12 18:04:00.000          LINK
# 4    2020-06-12 17:58:36.473         PHOTO
# ...                      ...           ...
# 3948 2020-06-07 18:34:23.499           NaN
# 3949 2020-06-07 18:34:14.371          LINK
# 3950 2020-06-07 18:32:36.554         PHOTO
# 3951 2020-06-07 18:31:53.600          LINK
# 3952 2020-06-07 18:30:13.618          LINK
#
#                                               Permalink  \
# 0     https://www.twitter.com/abagdadi/status/127150...
# 1     https://www.twitter.com/techvignesh/status/127...
# 2     https://www.twitter.com/ReworkAmerica/status/1...
# 3     https://www.nanjingmarketinggroup.com/blog/10-...
# 4     https://www.twitter.com/Milanowekpet/status/12...
# ...                                                 ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...
# 3949  https://www.twitter.com/mserracanta/status/126...
# 3950  https://www.twitter.com/IEAKwame/status/126969...
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...
# 3952  https://www.twitter.com/jakobssm/status/126969...
#
#                          Domain  Retweets     Message Type  \
# 0                   twitter.com       NaN  Twitter Retweet
# 1                   twitter.com       NaN  Twitter Retweet
# 2                   twitter.com       NaN  Twitter Mention
# 3     nanjingmarketinggroup.com       NaN        Blog Post
# 4                   twitter.com       NaN  Twitter Retweet
# ...                         ...       ...              ...
# 3948                twitter.com       NaN  Twitter Retweet
# 3949                twitter.com       1.0   Twitter Update
# 3950                twitter.com       NaN  Twitter Retweet
# 3951                twitter.com       NaN  Twitter Retweet
# 3952                twitter.com       2.0   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
# [3953 rows x 12 columns]

# %%
df.drop(['Retweets','CreatedTime','Domain'],axis=1,inplace=True)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message MediaTypeList  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...         PHOTO
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...         VIDEO
# 2     This @McKinsey article provides us with some f...          LINK
# 3     10 Chinese Market Trends Since COVID-19 Toggle...          LINK
# 4     RT @McKonGov In a war, leadership up and down ...         PHOTO
# ...                                                 ...           ...
# 3948  RT @McKinsey When can your region reopen? TY @...           NaN
# 3949             To read!! mckinsey.com/business-funct…          LINK
# 3950  RT @McKinsey When can your region reopen? This...         PHOTO
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...          LINK
# 3952  As cities end coronavirus lockdowns, public-tr...          LINK
#
#                                               Permalink     Message Type  \
# 0     https://www.twitter.com/abagdadi/status/127150...  Twitter Retweet
# 1     https://www.twitter.com/techvignesh/status/127...  Twitter Retweet
# 2     https://www.twitter.com/ReworkAmerica/status/1...  Twitter Mention
# 3     https://www.nanjingmarketinggroup.com/blog/10-...        Blog Post
# 4     https://www.twitter.com/Milanowekpet/status/12...  Twitter Retweet
# ...                                                 ...              ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...  Twitter Retweet
# 3949  https://www.twitter.com/mserracanta/status/126...   Twitter Update
# 3950  https://www.twitter.com/IEAKwame/status/126969...  Twitter Retweet
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...  Twitter Retweet
# 3952  https://www.twitter.com/jakobssm/status/126969...   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
# [3953 rows x 9 columns]

# %%
hashtags=""
for i in df['hashtag']:
    data=i.split("#")
    for j in data:
        if data!="":
            hashtags+=j
            hashtags+=" "

# %%
hashtags
# Out:
# ' COVID  FutureofWork   COVID     COVID   MedTech  Heathcare  SupplyChain    mckinsey  China  coronavirus  closedborders  India   COVID   COVID     MedTech  Heathcare  SupplyChain   COVID    COVID   covid  industry    Covid  LTWConnects      COVID  FutureofWork       COVID       telehealth  healthcare     GDP  Wellbeing   africa  covid   Coronavirus     GDP  Wellbeing   GDP  Wellbeing   COVID   COVID   Covid  LTWConnects   Covid  LTWConnects   COVID   COVID     telehealth  healthcare      digitalhealth  virtualhealth  healthcare  medtech  innovation  COVID  remotecare    COVID  FutureofWork   MedTech  Heathcare  SupplyChain   orangemoney     Covid  LTWConnects   Covid  LTWConnects    Covid  LTWConnects   Covid  LTWConnects   Covid  LTWConnects        covid  newnormal    MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain    COVID     riskmanagement  leadership  postcovid     COVID   COVID    COVID   Covid  GeorgeFloyd  SystemicRacism  BlackLivesMatter      MedTech  Heathcare  SupplyChain    omnichannel  digitaltransformation  cx   COVID    MedTech  Heathcare  SupplyChain   COVID  FutureofWork   COVID  BLM  economy  genderequality  LTW  damevivianhunt   covid   covid          Banking   mckinsey  covid          GDP  Wellbeing    GDP  Wellbeing        COVID  FutureofWork   covid  consumer    MedTech  Heathcare  SupplyChain    CFOs  COVID   MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain   COVID  NewNormal  Flexibility  HomeOffice  WorkSmarterAnywhere    newvalue  neweconomy  carefuleconomy   COVID   buildbackbetter  buildbackhappier      MedTech  Heathcare  SupplyChain    CFOs  COVID   Keepfactor   COVID   yycbiz  COVID  Here        ASAShotcrete  Concrete   MedTech  Heathcare  SupplyChain   strategy  insights  technology   MedTech  Heathcare  SupplyChain   strategy  insights  technology   RT  chartoftheday    PrivateEquity  investing   chartoftheday   chartoftheday      COVID  FutureofWork    COVID  FutureofWork   chartoftheday   chartoftheday   COVID   FemaleSummIT  FemaleSummIT  FemaleSummIT  McKWomen  McKCareers    COVID   COVID   COVID   COVID  FutureofWork   resilience      InnoVEXOnlineDemo   InnoVEXOnlineDemo    InnoVEXOnlineDemo   InnoVEXOnlineDemo   InnoVEXOnlineDemo   MedTech  Heathcare  SupplyChain        MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain   diversity  COVID     RT    MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain     COVID   MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain     MedTech  Heathcare  SupplyChain           Robots  Pandemic  fintech  futureofwork  covid  AI  ArtificialIntelligence  MachineLearning  robotics   COVID      COVID   MedTech  Heathcare  SupplyChain   digital  AI  data  remotework   DigitalTransformation  business  smallbusiness  smallbiz  shoplocal  sme  smb  manufacturing  innovation  localbusiness  office  productivity  construction  industrial  ERP  CRM  MRP  SaaS   COVID  wellbeing   MedTech  Heathcare  SupplyChain   women  clothing  outfits  makeover  style     MedTech  Heathcare  SupplyChain   COVID    consumer  Millennials  GenZ                                                                                                         automation  ArtificialIntelligence   RT  COVID   RT    MedTech  Heathcare  SupplyChain   crisis  covid  payments  Africa    ecommerce  trends  hotelmarkeiting  COVID    MedTech  Heathcare  SupplyChain     CFO  CEO  CIO  CDO  CMO  AI  innovation  digitaltransformation   InsightsonPrivateEquityampPrincipalInvestors    covid  construction  mckinsey    consumersentiment  economicrecovery   MedTech  Heathcare  SupplyChain    MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain    CEO  CIO  CDO  CMO  CFO  AI  bigdata  customerexperience  innovation  digitaltransformation   MedTech  Heathcare  SupplyChain   COVID  dataviz   MedTech  Heathcare  SupplyChain   chartoftheday  chartoftheday   MedTech  Heathcare  SupplyChain   MedTech  Heathcare  SupplyChain   MedTe ...

# %%
# Generate Word Cloud
fig=plt.figure(figsize=(12,8))
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
wordcloud = WordCloud(width = 500, height = 500, colormap='viridis', random_state=10).generate(hashtags)
plt.imshow(wordcloud) 
plt.axis("off");
fig.savefig("wordcloudoftags.jpg")

# %% [markdown]
# ### Sentiment Analysis

# %%
1 in [1,2,3]
# Out:
# True

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en_core_web_md==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.3.1/en_core_web_md-2.3.1.tar.gz (50.8 MB)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from en_core_web_md==2.3.1) (2.3.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.18.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.8.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.3)
# Requirement already satisfied: thinc==7.4.1 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (7.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.0.4)
# Requirement already satisfied: setuptools in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (50.3.0.post20201103)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.24.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (4.51.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aviru\anaconda3\envs\datasciencemachinelearning\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.25.11)
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py): started
#   Building wheel for en-core-web-md (setup.py): finished with status 'done'
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.3.1-py3-none-any.whl size=50916645 sha256=a9fb966ac0384ac748bb8879c83c54d3428aeacbfb82291f7742eb02ce423140
#   Stored in directory: C:\Users\aviru\AppData\Local\Temp\pip-ephem-wheel-cache-iqp2pzkj\wheels\b8\ae\ae\c63bae74a3b3e18b2fa35e179387e6cdeb03a1c479ed45c351
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.3.1
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
import en_core_web_md

# %%
model=en_core_web_md.load()

# %%
import string

# %%
model.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
def clean_message(lst):
    message=''
    for i in lst:
        if str(i) in model.Defaults.stop_words:
            continue
        elif str(i) in string.punctuation:
            continue
        elif str(i) in string.digits:
            continue
        else:
            message+=str(i)
            message+=" "
        
    return message

print(clean_message(df['splitted_message'].iloc[0]))
# Out:
# RT @McKinsey Beyond #COVID19 crisis, preparing jobs tomorrow challenge community EU. @McKinsey_MGI launched new report #FutureofWork Europe. mck.co/2YsrNgK https://t.co/OKDO2UTubS

# %%
df['semi_clean']=df['splitted_message'].apply(clean_message)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message MediaTypeList  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...         PHOTO
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...         VIDEO
# 2     This @McKinsey article provides us with some f...          LINK
# 3     10 Chinese Market Trends Since COVID-19 Toggle...          LINK
# 4     RT @McKonGov In a war, leadership up and down ...         PHOTO
# ...                                                 ...           ...
# 3948  RT @McKinsey When can your region reopen? TY @...           NaN
# 3949             To read!! mckinsey.com/business-funct…          LINK
# 3950  RT @McKinsey When can your region reopen? This...         PHOTO
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...          LINK
# 3952  As cities end coronavirus lockdowns, public-tr...          LINK
#
#                                               Permalink     Message Type  \
# 0     https://www.twitter.com/abagdadi/status/127150...  Twitter Retweet
# 1     https://www.twitter.com/techvignesh/status/127...  Twitter Retweet
# 2     https://www.twitter.com/ReworkAmerica/status/1...  Twitter Mention
# 3     https://www.nanjingmarketinggroup.com/blog/10-...        Blog Post
# 4     https://www.twitter.com/Milanowekpet/status/12...  Twitter Retweet
# ...                                                 ...              ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...  Twitter Retweet
# 3949  https://www.twitter.com/mserracanta/status/126...   Twitter Update
# 3950  https://www.twitter.com/IEAKwame/status/126969...  Twitter Retweet
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...  Twitter Retweet
# 3952  https://www.twitter.com/jakobssm/status/126969...   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag  \
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
#                                              semi_clean
# 0     RT @McKinsey Beyond #COVID19 crisis, preparing...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides food thought s...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In war, leadership ranks, adaptab...
# ...                                                 ...
# 3948  RT @McKinsey When region reopen? TY @McKinsey ...
# 3949            To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When region reopen? This local re...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
# [3953 rows x 10 columns]

# %%
#df.drop("semi_clean",axis=1,inplace=True)

# %%
def clean_text(message):
    clean_message=p.clean(message)
    return clean_message

clean_text(df['semi_clean'].iloc[0])
# Out:
# 'Beyond crisis, preparing jobs tomorrow challenge community EU. launched new report Europe.'

# %%
df['cleaned_message']=df['semi_clean'].apply(clean_text)

# %%
# Sentiment Analysis Fuction
def textblob_sentiment_calculator(message):
    cleaned_message=p.clean(message)
    blob=TextBlob(message)
    return blob.sentiment.polarity

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message MediaTypeList  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...         PHOTO
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...         VIDEO
# 2     This @McKinsey article provides us with some f...          LINK
# 3     10 Chinese Market Trends Since COVID-19 Toggle...          LINK
# 4     RT @McKonGov In a war, leadership up and down ...         PHOTO
# ...                                                 ...           ...
# 3948  RT @McKinsey When can your region reopen? TY @...           NaN
# 3949             To read!! mckinsey.com/business-funct…          LINK
# 3950  RT @McKinsey When can your region reopen? This...         PHOTO
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...          LINK
# 3952  As cities end coronavirus lockdowns, public-tr...          LINK
#
#                                               Permalink     Message Type  \
# 0     https://www.twitter.com/abagdadi/status/127150...  Twitter Retweet
# 1     https://www.twitter.com/techvignesh/status/127...  Twitter Retweet
# 2     https://www.twitter.com/ReworkAmerica/status/1...  Twitter Mention
# 3     https://www.nanjingmarketinggroup.com/blog/10-...        Blog Post
# 4     https://www.twitter.com/Milanowekpet/status/12...  Twitter Retweet
# ...                                                 ...              ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...  Twitter Retweet
# 3949  https://www.twitter.com/mserracanta/status/126...   Twitter Update
# 3950  https://www.twitter.com/IEAKwame/status/126969...  Twitter Retweet
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...  Twitter Retweet
# 3952  https://www.twitter.com/jakobssm/status/126969...   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag  \
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
#                                              semi_clean  \
# 0     RT @McKinsey Beyond #COVID19 crisis, preparing...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides food thought s...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In war, leadership ranks, adaptab...
# ...                                                 ...
# 3948  RT @McKinsey When region reopen? TY @McKinsey ...
# 3949            To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When region reopen? This local re...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                                         cleaned_message
# 0     Beyond crisis, preparing jobs tomorrow challen...
# 1     Were tracking impact jobs income levels, race,...
# 2     This article provides food thought start think...
# 3     Chinese Market Trends Since COVID-19 Toggle na...
# 4     In war, leadership ranks, adaptability, clear ...
# ...                                                 ...
# 3948                             When region reopen? TY
# 3949                                          To read!!
# 3950  When region reopen? This local response matrix...
# 3951  Starbucks China: Pre-Covid % digital orders, P...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
# [3953 rows x 11 columns]

# %%
df['polarity_score']=df['cleaned_message'].apply(sentiment_calculator)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message MediaTypeList  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...         PHOTO
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...         VIDEO
# 2     This @McKinsey article provides us with some f...          LINK
# 3     10 Chinese Market Trends Since COVID-19 Toggle...          LINK
# 4     RT @McKonGov In a war, leadership up and down ...         PHOTO
# ...                                                 ...           ...
# 3948  RT @McKinsey When can your region reopen? TY @...           NaN
# 3949             To read!! mckinsey.com/business-funct…          LINK
# 3950  RT @McKinsey When can your region reopen? This...         PHOTO
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...          LINK
# 3952  As cities end coronavirus lockdowns, public-tr...          LINK
#
#                                               Permalink     Message Type  \
# 0     https://www.twitter.com/abagdadi/status/127150...  Twitter Retweet
# 1     https://www.twitter.com/techvignesh/status/127...  Twitter Retweet
# 2     https://www.twitter.com/ReworkAmerica/status/1...  Twitter Mention
# 3     https://www.nanjingmarketinggroup.com/blog/10-...        Blog Post
# 4     https://www.twitter.com/Milanowekpet/status/12...  Twitter Retweet
# ...                                                 ...              ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...  Twitter Retweet
# 3949  https://www.twitter.com/mserracanta/status/126...   Twitter Update
# 3950  https://www.twitter.com/IEAKwame/status/126969...  Twitter Retweet
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...  Twitter Retweet
# 3952  https://www.twitter.com/jakobssm/status/126969...   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag  \
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
#                                              semi_clean  \
# 0     RT @McKinsey Beyond #COVID19 crisis, preparing...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides food thought s...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In war, leadership ranks, adaptab...
# ...                                                 ...
# 3948  RT @McKinsey When region reopen? TY @McKinsey ...
# 3949            To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When region reopen? This local re...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                                         cleaned_message  polarity_score
# 0     Beyond crisis, preparing jobs tomorrow challen...        0.136364
# 1     Were tracking impact jobs income levels, race,...       -0.100000
# 2     This article provides food thought start think...        0.143182
# 3     Chinese Market Trends Since COVID-19 Toggle na...        0.066662
# 4     In war, leadership ranks, adaptability, clear ...        0.125000
# ...                                                 ...             ...
# 3948                             When region reopen? TY        0.000000
# 3949                                          To read!!        0.000000
# 3950  When region reopen? This local response matrix...        0.000000
# 3951  Starbucks China: Pre-Covid % digital orders, P...        0.000000
# 3952  As cities end coronavirus lockdowns, public-tr...        0.050000
#
# [3953 rows x 12 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
# Sentiment Analysis Fuction
def vader_sentiment_calculator(message):
    score1 = analyser.polarity_scores(message)
    return score1.get('compound')

vader_sentiment_calculator(df['cleaned_message'].iloc[0])
# Out:
# -0.5106

# %%
df["vader_sentiment_score"]=df['cleaned_message'].apply(vader_sentiment_calculator)

# %%
def sentiment_category(score):
    if score >= 0.05:
        return "Positive"
    elif score > -0.05 and score <0.05:
        return "Neutral"
    elif score <= -0.05 : 
        return "Negative"

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message MediaTypeList  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...         PHOTO
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...         VIDEO
# 2     This @McKinsey article provides us with some f...          LINK
# 3     10 Chinese Market Trends Since COVID-19 Toggle...          LINK
# 4     RT @McKonGov In a war, leadership up and down ...         PHOTO
# ...                                                 ...           ...
# 3948  RT @McKinsey When can your region reopen? TY @...           NaN
# 3949             To read!! mckinsey.com/business-funct…          LINK
# 3950  RT @McKinsey When can your region reopen? This...         PHOTO
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...          LINK
# 3952  As cities end coronavirus lockdowns, public-tr...          LINK
#
#                                               Permalink     Message Type  \
# 0     https://www.twitter.com/abagdadi/status/127150...  Twitter Retweet
# 1     https://www.twitter.com/techvignesh/status/127...  Twitter Retweet
# 2     https://www.twitter.com/ReworkAmerica/status/1...  Twitter Mention
# 3     https://www.nanjingmarketinggroup.com/blog/10-...        Blog Post
# 4     https://www.twitter.com/Milanowekpet/status/12...  Twitter Retweet
# ...                                                 ...              ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...  Twitter Retweet
# 3949  https://www.twitter.com/mserracanta/status/126...   Twitter Update
# 3950  https://www.twitter.com/IEAKwame/status/126969...  Twitter Retweet
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...  Twitter Retweet
# 3952  https://www.twitter.com/jakobssm/status/126969...   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag  \
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
#                                              semi_clean  \
# 0     RT @McKinsey Beyond #COVID19 crisis, preparing...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides food thought s...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In war, leadership ranks, adaptab...
# ...                                                 ...
# 3948  RT @McKinsey When region reopen? TY @McKinsey ...
# 3949            To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When region reopen? This local re...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                                         cleaned_message  polarity_score  \
# 0     Beyond crisis, preparing jobs tomorrow challen...        0.136364
# 1     Were tracking impact jobs income levels, race,...       -0.100000
# 2     This article provides food thought start think...        0.143182
# 3     Chinese Market Trends Since COVID-19 Toggle na...        0.066662
# 4     In war, leadership ranks, adaptability, clear ...        0.125000
# ...                                                 ...             ...
# 3948                             When region reopen? TY        0.000000
# 3949                                          To read!!        0.000000
# 3950  When region reopen? This local response matrix...        0.000000
# 3951  Starbucks China: Pre-Covid % digital orders, P...        0.000000
# 3952  As cities end coronavirus lockdowns, public-tr...        0.050000
#
#       vader_sentiment_score
# 0                   -0.5106
# 1                    0.0000
# 2                   -0.4588
# 3                    0.9985
# 4                   -0.8271
# ...                     ...
# 3948                 0.5160
# 3949                 0.0000
# 3950                 0.2500
# 3951                 0.0000
# 3952                 0.3182
#
# [3953 rows x 13 columns]

# %%
df['sentiment_category']=df['vader_sentiment_score'].apply(sentiment_category)

# %%
df
# Out:
#      OriginalAuthor       OriginalAuthorProfileLink  \
# 0          McKinsey    https://twitter.com/McKinsey
# 1          McKinsey    https://twitter.com/McKinsey
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4          McKonGov    https://twitter.com/McKonGov
# ...             ...                             ...
# 3948       McKinsey    https://twitter.com/McKinsey
# 3949            NaN                             NaN
# 3950       McKinsey    https://twitter.com/McKinsey
# 3951     retailgeek  https://twitter.com/retailgeek
# 3952            NaN                             NaN
#
#                                         Title  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3     10 Chinese Market Trends Since COVID-19
# 4                                         NaN
# ...                                       ...
# 3948                                      NaN
# 3949                                      NaN
# 3950                                      NaN
# 3951                                      NaN
# 3952                                      NaN
#
#                                                 Message MediaTypeList  \
# 0     RT @McKinsey Beyond the #COVID19 crisis, prepa...         PHOTO
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...         VIDEO
# 2     This @McKinsey article provides us with some f...          LINK
# 3     10 Chinese Market Trends Since COVID-19 Toggle...          LINK
# 4     RT @McKonGov In a war, leadership up and down ...         PHOTO
# ...                                                 ...           ...
# 3948  RT @McKinsey When can your region reopen? TY @...           NaN
# 3949             To read!! mckinsey.com/business-funct…          LINK
# 3950  RT @McKinsey When can your region reopen? This...         PHOTO
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...          LINK
# 3952  As cities end coronavirus lockdowns, public-tr...          LINK
#
#                                               Permalink     Message Type  \
# 0     https://www.twitter.com/abagdadi/status/127150...  Twitter Retweet
# 1     https://www.twitter.com/techvignesh/status/127...  Twitter Retweet
# 2     https://www.twitter.com/ReworkAmerica/status/1...  Twitter Mention
# 3     https://www.nanjingmarketinggroup.com/blog/10-...        Blog Post
# 4     https://www.twitter.com/Milanowekpet/status/12...  Twitter Retweet
# ...                                                 ...              ...
# 3948  https://www.twitter.com/Nicochan33/status/1269...  Twitter Retweet
# 3949  https://www.twitter.com/mserracanta/status/126...   Twitter Update
# 3950  https://www.twitter.com/IEAKwame/status/126969...  Twitter Retweet
# 3951  https://www.twitter.com/OmerAtakoglu/status/12...  Twitter Retweet
# 3952  https://www.twitter.com/jakobssm/status/126969...   Twitter Update
#
#                                        splitted_message  \
# 0     [RT, @McKinsey, Beyond, the, #COVID19, crisis,...
# 1     [RT, @McKinsey, We’re, tracking, #COVID19’s, i...
# 2     [This, @McKinsey, article, provides, us, with,...
# 3     [10, Chinese, Market, Trends, Since, COVID-19,...
# 4     [RT, @McKonGov, In, a, war,, leadership, up, a...
# ...                                                 ...
# 3948  [RT, @McKinsey, When, can, your, region, reope...
# 3949         [To, read!!, mckinsey.com/business-funct…]
# 3950  [RT, @McKinsey, When, can, your, region, reope...
# 3951  [RT, @retailgeek, Starbucks, China:, Pre-Covid...
# 3952  [As, cities, end, coronavirus, lockdowns,, pub...
#
#                                                 hashtag  \
# 0                                 #COVID #FutureofWork
# 1                                               #COVID
# 2
# 3
# 4                                               #COVID
# ...                                                 ...
# 3948  #ehealth #mhealth #GDP #AI #IoT #fintech #medt...
# 3949
# 3950                           #chartoftheday #dataviz
# 3951
# 3952                             #publictransit #dktrp
#
#                                              semi_clean  \
# 0     RT @McKinsey Beyond #COVID19 crisis, preparing...
# 1     RT @McKinsey We’re tracking #COVID19’s impact ...
# 2     This @McKinsey article provides food thought s...
# 3     10 Chinese Market Trends Since COVID-19 Toggle...
# 4     RT @McKonGov In war, leadership ranks, adaptab...
# ...                                                 ...
# 3948  RT @McKinsey When region reopen? TY @McKinsey ...
# 3949            To read!! mckinsey.com/business-funct…
# 3950  RT @McKinsey When region reopen? This local re...
# 3951  RT @retailgeek Starbucks China: Pre-Covid 15% ...
# 3952  As cities end coronavirus lockdowns, public-tr...
#
#                                         cleaned_message  polarity_score  \
# 0     Beyond crisis, preparing jobs tomorrow challen...        0.136364
# 1     Were tracking impact jobs income levels, race,...       -0.100000
# 2     This article provides food thought start think...        0.143182
# 3     Chinese Market Trends Since COVID-19 Toggle na...        0.066662
# 4     In war, leadership ranks, adaptability, clear ...        0.125000
# ...                                                 ...             ...
# 3948                             When region reopen? TY        0.000000
# 3949                                          To read!!        0.000000
# 3950  When region reopen? This local response matrix...        0.000000
# 3951  Starbucks China: Pre-Covid % digital orders, P...        0.000000
# 3952  As cities end coronavirus lockdowns, public-tr...        0.050000
#
#       vader_sentiment_score sentiment_category
# 0                   -0.5106           Negative
# 1                    0.0000            Neutral
# 2                   -0.4588           Negative
# 3                    0.9985           Positive
# 4                   -0.8271           Negative
# ...                     ...                ...
# 3948                 0.5160           Positive
# 3949                 0.0000            Neutral
# 3950                 0.2500           Positive
# 3951                 0.0000            Neutral
# 3952                 0.3182           Positive
#
# [3953 rows x 14 columns]

# %%
data_platform=dict(df['sentiment_category'].value_counts())
for key in data_platform:
    data_platform[key]=data_platform[key]/len(df)
    print(data_platform[key])
# Out:
# 0.5575512269162661
# 0.2251454591449532
# 0.21730331393878066

# %%
fig=plt.figure(figsize=(12,8))
plt.title("Sentiment of The Data")
plt.xlabel("Sentiment Categories")
plt.ylabel("Count of Tweets")
sns.barplot(x=list(data_platform.keys()),y=list(data_platform.values()),data=df)
fig.savefig("SentimentOfData.png")
